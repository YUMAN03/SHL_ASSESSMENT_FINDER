# %%
category_dict = {
    "A": "Ability & Aptitude",
    "B": "Biodata & Situational Judgement",
    "C": "Competencies",
    "D": "Development & 360",
    "E": "Assessment Exercises",
    "K": "Knowledge & Skills",
    "P": "Personality & Behavior",
    "S": "Simulations"
}
def convert_test_type_string(test_str):
    if test_str.startswith("Test Type:"):
        codes = test_str.replace("Test Type:", "").strip()
        full_names = [category_dict.get(char, f"Unknown({char})") for char in codes]
        return "Test Type: " + ", ".join(full_names)
    return test_str

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import re

# Inside your loop


BASE_URL = "https://www.shl.com"
CATALOG_URL = BASE_URL + "/solutions/products/product-catalog/?start="

headers = {
    "User-Agent": "Mozilla/5.0"
}

def get_product_links(URL):
    remote=[]
    adap=[]
    links = []
    for page_url in URL:      
        response = requests.get(page_url, headers=headers)
        time.sleep(4)
        soup = BeautifulSoup(response.text, 'html.parser')

        div=soup.find("div", class_="custom__table-responsive")
        trs=div.find_all("tr")
        for tr in trs:
            td=tr.find("td", class_="custom__table-heading__title") 
            if not td:
                continue
            rem=tr.find_all("td", class_="custom__table-heading__general")
            if not rem:
                continue            
            a_tag = td.find("a")
            if a_tag:
                href = a_tag['href']
                title = a_tag.text.strip()
                full_url = BASE_URL + href
                links.append((title, full_url))
            td1 = rem[0]
            td2 = rem[1]
            span=td1.find("span", class_="catalogue__circle -yes")
            if span:
                remote.append(1)
            else:
                remote.append(0)    
            span= td2.find("span", class_="catalogue__circle -yes")
            if span:
                adap.append(1)
            else:
                adap.append(0)
    return links,remote,adap

def get_description(product_url):
    response = requests.get(product_url, headers=headers)
    if response.status_code != 200:
        print(f"❌ Failed to fetch {product_url}")
        return "Description not available."

    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all description sections based on partial class match
    desc_sections = soup.find_all("div", class_=lambda c: c and c.startswith("product-catalogue-training-calendar__row"))

    description_parts = ""
    for section in desc_sections:
        paragraphs = section.find_all("p")
        for p in paragraphs:
            check = section.find("h4")
            if not check:
                continue
            if check.get_text(strip=True) == "Downloads":
                continue
            text = p.get_text(strip=True)
            text=convert_test_type_string(text)
            if text:   
                text = re.sub(r'\s+', ' ', text).strip()
                if(text=="Remote Testing:"):
                    continue
                description_parts+=text+" "

    final_description = description_parts if description_parts else "Description not found."
    return final_description

def main():
    URL=[]
    for i in range(0,373,12):
        url=""
        url=CATALOG_URL+str(i)
        url+="&type=1"
        URL.append(url)
    for i in range(0,133,12):
        url=""
        url=CATALOG_URL+str(i)
        url+="&type=2"
        URL.append(url)    
    products,remote,adap = get_product_links(URL)
    all_data = []
    i=0
    for title, url in products:
        print(f"Scraping: {title}")
        description = get_description(url)    
        if remote[i]==1:
            remo="Yes"
            description+=" Remote Testing"
        else:
            remo="No"
        if adap[i]==1:  
            ada="Yes"
            description+=" Adaptive/IRT"
        else:
            ada="No"    
        i+=1    
        all_data.append([title, f"{url}",remo,ada, description])  # Be nice to the server

    # Save to CSV
    with open("shl_products.csv", "w", newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["Title", "URL","Remote Testing","ADAPTIVE/IRT","Description"])
        writer.writerows(all_data)

    print("Scraping completed. Data saved to shl_products.csv")

if __name__ == "__main__":
    main()
# Out:
# Scraping: Account Manager Solution
# Scraping: Administrative Professional - Short Form
# Scraping: Agency Manager Solution
# Scraping: Apprentice + 8.0 Job Focused Assessment
# Scraping: Apprentice 8.0 Job Focused Assessment
# Scraping: Bank Administrative Assistant - Short Form
# Scraping: Bank Collections Agent - Short Form
# Scraping: Bank Operations Supervisor - Short Form
# Scraping: Bilingual Spanish Reservation Agent Solution
# Scraping: Bookkeeping, Accounting, Auditing Clerk Short Form
# Scraping: Branch Manager - Short Form
# Scraping: Cashier Solution
# Scraping: Adobe Experience Manager (New)
# Scraping: Adobe Photoshop CC
# Scraping: Aeronautical Engineering (New)
# Scraping: Aerospace Engineering (New)
# Scraping: Agile Software Development
# Scraping: Agile Testing (New)
# Scraping: AI Skills
# Scraping: Amazon Web Services (AWS) Development (New)
# Scraping: Android Development (New)
# Scraping: Angular 6 (New)
# Scraping: AngularJS (New)
# Scraping: Apache Hadoop (New)
# Scraping: Apache Hadoop Extensions (New)
# Scraping: Apache HBase (New)
# Scraping: Apache Hive (New)
# Scraping: Apache Kafka (New)
# Scraping: Apache Pig (New)
# Scraping: Apache Spark (New)
# Scraping: ASP .NET with C# (New)
# Scraping: ASP.NET 4.5
# Scraping: Assessment and Development Center Exercises
# Scraping: Automata - Fix (New)
# Scraping: Automata - SQL (New)
# Scraping: Automata (New)
# Scraping: Automata Data Science (New)
# Scraping: Automata Data Science Pro (New)
# Scraping: Automata Front End
# Scraping: Automata Pro (New)
# Scraping: Automata Selenium
# Scraping: Automation Anywhere RPA Development (New)
# Scraping: Automotive Engineering (New)
# Scraping: Basic Biology (New)
# Scraping: Basic Computer Literacy (Windows 10) (New)
# Scraping: Basic Statistics (New)
# Scraping: Biochemistry (New)
# Scraping: Biotech Lab Techniques (New)
# Scraping: BizTalk (New)
# Scraping: Business Communication (adaptive)
# Scraping: Business Communications
# Scraping: C Programming (New)
# Scraping: C# Programming (New)
# Scraping: C++ Programming (New)
# Scraping: Cardiology and Diabetes Management (New)
# Scraping: Ceramic Engineering (New)
# Scraping: Chemical Engineering (New)
# Scraping: Cisco AppDynamics (New)
# Scraping: Civil Engineering (New)
# Scraping: Cloud Computing (New)
# Scraping: COBOL Programming (New)
# Scraping: Computer Science (New)
# Scraping: Contact Center Call Simulation (New)
# Scraping: Conversational Multichat Simulation
# Scraping: Core Java (Advanced Level) (New)
# Scraping: Core Java (Entry Level) (New)
# Scraping: Count Out The Money
# Scraping: CSS3 (New)
# Scraping: Culinary Skills (New)
# Scraping: Customer Service Phone Simulation
# Scraping: Customer Service Phone Solution
# Scraping: Cyber Risk (New)
# Scraping: Data Entry (New)
# Scraping: Data Entry Alphanumeric Split Screen - US
# Scraping: Data Entry Numeric Split Screen - US
# Scraping: Data Entry Ten Key Split Screen
# Scraping: Data Science (New)
# Scraping: Data Warehousing Concepts
# Scraping: Dependability and Safety Instrument (DSI)
# Scraping: Dermatology (New)
# Scraping: Desktop Support (New)
# Scraping: Digital Advertising (New)
# Scraping: Digital Readiness Development Report - IC
# Scraping: Digital Readiness Development Report - Manager
# Scraping: Docker (New)
# Scraping: Dojo (New)
# Scraping: Drupal (New)
# Scraping: DSI v1.1 Interpretation Report
# Scraping: Econometrics (New)
# Scraping: Economics (New)
# Scraping: Electrical and Electronics Engineering (New)
# Scraping: Electrical Engineering (New)
# Scraping: Electronics & Telecommunications Engineering (New)
# Scraping: Electronics and Embedded Systems Engineering (New)
# Scraping: Electronics and Semiconductor Engineering (New)
# Scraping: English Comprehension (New)
# Scraping: Enterprise Java Beans (New)
# Scraping: Enterprise Leadership Report 1.0
# Scraping: Enterprise Leadership Report 2.0
# Scraping: Entry Level Cashier Solution
# Scraping: Entry Level Customer Serv-Retail & Contact Center
# Scraping: Entry Level Customer Service (General) Solution
# Scraping: Entry Level Hotel Front Desk Solution
# Scraping: Entry Level Sales Solution
# Scraping: Entry Level Technical Support Solution
# Scraping: ETL Testing (New)
# Scraping: Executive Scenarios
# Scraping: Executive Scenarios Narrative Report
# Scraping: Account Manager Solution
# Scraping: Administrative Professional - Short Form
# Scraping: Agency Manager Solution
# Scraping: Apprentice + 8.0 Job Focused Assessment
# Scraping: Apprentice 8.0 Job Focused Assessment
# Scraping: Bank Administrative Assistant - Short Form
# Scraping: Bank Collections Agent - Short Form
# Scraping: Bank Operations Supervisor - Short Form
# Scraping: Bilingual Spanish Reservation Agent Solution
# Scraping: Bookkeeping, Accounting, Auditing Clerk Short Form
# Scraping: Branch Manager - Short Form
# Scraping: Cashier Solution
# Scraping: Fundamentals of Chemistry (New)
# Scraping: Fundamentals of Physics (New)
# Scraping: General Diseases (New)
# Scraping: Geoinformatics Engineering (New)
# Scraping: Geoscience Engineering (New)
# Scraping: GIT (New)
# Scraping: Global Skills Assessment
# Scraping: Graduate Scenarios
# Scraping: Graduate Scenarios Narrative Report
# Scraping: Graduate Scenarios Profile Report
# Scraping: Hibernate (New)
# Scraping: HIPAA (Security)
# Scraping: HiPo Assessment Report 1.0
# Scraping: HiPo Assessment Report 2.0
# Scraping: HiPo Unlocking Potential Report 2.0
# Scraping: Housekeeping (New)
# Scraping: HTML/CSS (New)
# Scraping: HTML5 (New)
# Scraping: Human Resources (New)
# Scraping: IBM DataStage (New)
# Scraping: IBM Sterling Order Management System (New)
# Scraping: Industrial Engineering (New)
# Scraping: Informatica (Architecture) (New)
# Scraping: Informatica (Developer) (New)
# Scraping: Instrumentation Engineering (New)
# Scraping: Interpersonal Communications
# Scraping: Interviewing and Hiring Concepts (U.S.)
# Scraping: iOS Development (New)
# Scraping: ITIL (IT Infrastructure Library) (New)
# Scraping: Java 2 Platform Enterprise Edition 1.4 Fundamental
# Scraping: Java 8 (New)
# Scraping: Java Design Patterns (New)
# Scraping: Java Frameworks (New)
# Scraping: Java Platform Enterprise Edition 7 (Java EE 7)
# Scraping: Java Web Services (New)
# Scraping: JavaScript (New)
# Scraping: Jenkins (New)
# Scraping: Job Control Language (New)
# Scraping: jQuery (New)
# Scraping: Kubernetes (New)
# Scraping: Linux Administration (New)
# Scraping: Linux Operating System
# Scraping: Linux Programming (General)
# Scraping: Load Runner (New)
# Scraping: Management Scenarios
# Scraping: Managerial Scenarios Candidate Report
# Scraping: Managerial Scenarios Narrative Report
# Scraping: Managerial Scenarios Profile Report
# Scraping: Manual Testing (New)
# Scraping: Manufac. & Indust. - Mechanical & Vigilance 8.0
# Scraping: Manufac. & Indust. - Safety & Dependability 8.0
# Scraping: Manufacturing & Industrial - Essential Focus 8.0
# Scraping: Manufacturing & Industrial - Mechanical Focus 8.0
# Scraping: Manufacturing & Industrial - Vigilance Focus 8.0
# Scraping: Marketing (New)
# Scraping: Maven (New)
# Scraping: Mechanical Engineering (New)
# Scraping: Mechatronics Engineering (New)
# Scraping: Medical Terminology (New)
# Scraping: Metallurgical Engineering (New)
# Scraping: MFS 360 Enterprise Leadership Report
# Scraping: MFS 360 UCF Group Report
# Scraping: MFS 360 UCF Performance Potential Dev Tips Report
# Scraping: MFS 360 UCF Standard Report
# Scraping: Micro Focus Unified Functional Testing (New)
# Scraping: Microservices (New)
# Scraping: Microsoft Dynamics Development (New)
# Scraping: Microsoft Excel 365 - Essentials (New)
# Scraping: Microsoft Excel 365 (New)
# Scraping: Microsoft Outlook 2013 (adaptive)
# Scraping: Microsoft PowerPoint 365 - Essentials (New)
# Scraping: Microsoft SQL Server 2014 Programming
# Scraping: Microsoft Windows Server 2012 Administration
# Scraping: Microsoft Word 365 - Essentials (New)
# Scraping: Microsoft Word 365 (New)
# Scraping: Mineral Engineering (New)
# Scraping: Mining Engineering (New)
# Scraping: Mobility (New)
# Scraping: Molecular Biology (New)
# Scraping: MongoDB (New)
# Scraping: Motivation Questionnaire MQM5
# Scraping: MQ Candidate Motivation Report
# Scraping: MQ Employee Motivation Report
# Scraping: MQ Motivation Report Pack
# Scraping: MQ Profile
# Scraping: MS Access (New)
# Scraping: MS Excel (New)
# Scraping: MS Office Basic Computer Literacy (New)
# Scraping: MS Office Basic Computer Literacy (Sim) (New)
# Scraping: MS PowerPoint (New)
# Scraping: MS Word (New)
# Scraping: MuleSoft Development (New)
# Scraping: Multitasking Ability
# Scraping: Networking and Implementation (New)
# Scraping: Node.js (New)
# Scraping: Nursing (New)
# Scraping: Occupational Personality Questionnaire OPQ32r
# Scraping: Operations Management (New)
# Scraping: OPQ Candidate Plus Report
# Scraping: OPQ Candidate Report 2.0
# Scraping: OPQ Emotional Intelligence Report
# Scraping: OPQ Leadership Report
# Scraping: OPQ Manager Plus Report
# Scraping: OPQ Manager Plus Report 2.0
# Scraping: OPQ Maximising your Learning Report
# Scraping: OPQ MQ Sales Report
# Scraping: OPQ Premium Plus Report
# Scraping: OPQ Premium Plus Report 2.0
# Scraping: Account Manager Solution
# Scraping: Administrative Professional - Short Form
# Scraping: Agency Manager Solution
# Scraping: Apprentice + 8.0 Job Focused Assessment
# Scraping: Apprentice 8.0 Job Focused Assessment
# Scraping: Bank Administrative Assistant - Short Form
# Scraping: Bank Collections Agent - Short Form
# Scraping: Bank Operations Supervisor - Short Form
# Scraping: Bilingual Spanish Reservation Agent Solution
# Scraping: Bookkeeping, Accounting, Auditing Clerk Short Form
# Scraping: Branch Manager - Short Form
# Scraping: Cashier Solution
# Scraping: Oracle DBA (Advanced Level) (New)
# Scraping: Oracle DBA (Entry Level) (New)
# Scraping: Oracle PL/SQL (New)
# Scraping: Oracle WebLogic Server (New)
# Scraping: Organic Chemistry (New)
# Scraping: Paint Technology (New)
# Scraping: Pediatrics (New)
# Scraping: Pega Development (New)
# Scraping: Perl (New)
# Scraping: Petrochemical Engineering (New)
# Scraping: Petroleum Engineering (New)
# Scraping: Pharmaceutical Analysis (New)
# Scraping: Pharmaceutical Chemistry (New)
# Scraping: Pharmaceutical Science (New)
# Scraping: Pharmaceutics (New)
# Scraping: Pharmacology (New)
# Scraping: PHP (New)
# Scraping: PJM Development Report
# Scraping: PJM Selection Report
# Scraping: Polymer Engineering (New)
# Scraping: Power Electronics and Drives (New)
# Scraping: Power System Engineering (New)
# Scraping: Prism (New)
# Scraping: Production and Industrial Engineering (New)
# Scraping: Production Engineering (New)
# Scraping: Programming Concepts
# Scraping: Project Management (2013)
# Scraping: Proofreading v1
# Scraping: Python (New)
# Scraping: R Programming (New)
# Scraping: ReactJS (New)
# Scraping: Reading Comprehension - English v1
# Scraping: Reading Comprehension - Spanish v1
# Scraping: Reading Comprehension v2
# Scraping: RemoteWorkQ
# Scraping: RemoteWorkQ Manager Report
# Scraping: RemoteWorkQ Participant Report
# Scraping: RESTful Web Services (New)
# Scraping: Retail Sales and Service Simulation
# Scraping: Reviewing Forms - US (R1)
# Scraping: Ruby (New)
# Scraping: Ruby on Rails (New)
# Scraping: Sales & Service Phone Simulation
# Scraping: Sales & Service Phone Solution
# Scraping: Sales Interview Guide
# Scraping: Sales Profiler Cards
# Scraping: Sales Transformation 1.0 - Individual Contributor
# Scraping: Sales Transformation 2.0 - Individual Contributor
# Scraping: Sales Transformation Report 1.0 - Sales Manager
# Scraping: Sales Transformation Report 2.0 - Sales Manager
# Scraping: Salesforce Development (New)
# Scraping: SAP ABAP (Advanced Level) (New)
# Scraping: SAP ABAP (Intermediate Level) (New)
# Scraping: SAP Basis (New)
# Scraping: SAP Business Objects WebI (New)
# Scraping: SAP BW (Business Warehouse) (New)
# Scraping: SAP HCM (Human Capital Management) (New)
# Scraping: SAP Hybris (New)
# Scraping: SAP Materials Management (New)
# Scraping: SAP SD (Sales and Distribution) (New)
# Scraping: Search Engine Optimization (New)
# Scraping: Selenium (New)
# Scraping: Shell Scripting (New)
# Scraping: SHL Verify Interactive - Inductive Reasoning
# Scraping: SHL Verify Interactive – Deductive Reasoning
# Scraping: SHL Verify Interactive – Numerical Reasoning
# Scraping: SHL Verify Interactive G+
# Scraping: SHL Verify Interactive Numerical Calculation
# Scraping: Siebel Development (New)
# Scraping: Smart Interview Live
# Scraping: Smart Interview Live Coding
# Scraping: Smart Interview On Demand
# Scraping: Social Media (New)
# Scraping: Software Business Analysis
# Scraping: SonarQube (New)
# Scraping: Spelling (U.S.) (New)
# Scraping: Split Screen Typing Test - Form 1
# Scraping: Spring (New)
# Scraping: SQL (New)
# Scraping: SQL Server (New)
# Scraping: SQL Server Analysis Services (SSAS) (New)
# Scraping: SQL Server Integration Services (SSIS) (New)
# Scraping: SQL Server Reporting Services (SSRS) (New)
# Scraping: Statistical Analysis System (New)
# Scraping: Struts (New)
# Scraping: SVAR - Spoken English (AUS)
# Scraping: SVAR - Spoken English (Indian Accent)  (New)
# Scraping: SVAR - Spoken English (U.K.)
# Scraping: SVAR - Spoken English (US)  (New)
# Scraping: SVAR - Spoken French (Canadian) (New)
# Scraping: SVAR - Spoken French (European) (New)
# Scraping: SVAR - Spoken Spanish (Castilian) (New)
# Scraping: SVAR - Spoken Spanish (North American) (New)
# Scraping: Swing (New)
# Scraping: Tableau (New)
# Scraping: Telecommunications Engineering (New)
# Scraping: Teradata Development (New)
# Scraping: Time Management (U.S.)
# Scraping: Training Development
# Scraping: Typing (New)
# Scraping: UiPath RPA Development (New)
# Scraping: Universal Competency Framework Interview Guide
# Scraping: Universal Competency Framework Job profiling guide
# Scraping: Universal Competency Framework Profiler Cards (44)
# Scraping: UNIX (New)
# Scraping: VB.NET (New)
# Scraping: Verify - Deductive Reasoning
# Scraping: Verify - Following Instructions
# Scraping: Verify - G+
# Scraping: Verify - General Ability Screen
# Scraping: Verify - Inductive Reasoning (2014)
# Scraping: Verify - Numerical Ability
# Scraping: Verify - Technical Checking - Next Generation
# Scraping: Verify - Verbal Ability - Next Generation
# Scraping: Verify - Working with Information
# Scraping: Verify G+ - Ability Test Report
# Scraping: Verify G+ - Candidate Report
# Scraping: Verify Interactive Ability Report
# Scraping: Verify Interactive G+ Candidate Report
# Scraping: Verify Interactive G+ Report
# Scraping: Verify Interactive Process Monitoring
# Scraping: Virtual Assessment and Development Centers
# Scraping: Visual Basic for Applications (New)
# Scraping: Visual Comparison - UK
# Scraping: Visual Comparison - US
# Scraping: VLSI and Embedded Systems (New)
# Scraping: What Is The Value - US
# Scraping: Workplace Administration Skills (New)
# Scraping: Workplace Health and Safety (New)
# Scraping: WriteX - Email Writing (Customer Service) (New)
# Scraping: WriteX - Email Writing (Managerial) (New)
# Scraping: WriteX - Email Writing (Sales) (New)
# Scraping: Written English v1
# Scraping: Written Spanish
# Scraping: Zabbix (New)
# Scraping: 360 Digital Report
# Scraping: 360° Multi-Rater Feedback System (MFS)
# Scraping: Account Manager Solution
# Scraping: Administrative Professional - Short Form
# Scraping: Agency Manager Solution
# Scraping: Apprentice + 8.0 Job Focused Assessment
# Scraping: Apprentice 8.0 Job Focused Assessment
# Scraping: Bank Administrative Assistant - Short Form
# Scraping: Bank Collections Agent - Short Form
# Scraping: Bank Operations Supervisor - Short Form
# Scraping: Bilingual Spanish Reservation Agent Solution
# Scraping: Bookkeeping, Accounting, Auditing Clerk Short Form
# Scraping: Branch Manager - Short Form
# Scraping: Cashier Solution
# Scraping: Claims/Operations Supervisor Solution
# Scraping: Contact Center Customer Service + 8.0
# Scraping: Contact Center Customer Service 8.0
# Scraping: Contact Center Manager - Short Form
# Scraping: Contact Center Sales & Service + 8.0
# Scraping: Contact Center Sales & Service 8.0
# Scraping: Contact Center Team Lead/Coach - Short Form
# Scraping: Contact Centre Agent Solution - UK
# Scraping: Customer Service - Short Form
# Scraping: Customer Service - Short Form - UK
# Scraping: Customer Service with Sales - Short Form
# Scraping: Director - Short Form
# Scraping: District/Regional Manager Solution
# Scraping: Entry Level Cashier 7.1 (Americas)
# Scraping: Entry Level Cashier 7.1 (International)
# Scraping: Entry Level Customer Service 7.1 (Americas)
# Scraping: Entry Level Customer Service 7.1 (International)
# Scraping: Entry Level Customer Service 7.1 (South Africa)
# Scraping: Entry level Sales 7.1 (Americas)
# Scraping: Entry level Sales 7.1 (International)
# Scraping: Entry Level Sales Sift Out 7.1
# Scraping: Event Sales Manager Solution
# Scraping: Executive - Short Form
# Scraping: Financial Professional - Short Form
# Scraping: Financial Services Representative Solution
# Scraping: Front Desk Associate Solution
# Scraping: Gaming Associate Solution
# Scraping: Gaming Manager Solution
# Scraping: General Entry Level - All Industries 7.0 Solution
# Scraping: General Entry Level - All Industries 7.1 Solution
# Scraping: General Entry Level - All Industries 7.1(Americas)
# Scraping: General Entry Level – Data Entry 7.0 Solution
# Scraping: Graduate + 8.0 Job Focused Assessment
# Scraping: Graduate 7.1 Job Focused Assessment
# Scraping: Graduate 8.0 Job Focused Assessment
# Scraping: Guest Service Team 7.0 Solution
# Scraping: Guest Services Associate Solution
# Scraping: Healthcare Aide 7.0 Solution
# Scraping: Healthcare Call Center Agent Solution
# Scraping: Healthcare Service Associate Solution
# Scraping: Healthcare Support Specialist Solution
# Scraping: Home Health Aide Solution
# Scraping: Hospitality Manager Solution
# Scraping: Host Solution
# Scraping: Industrial - Entry Level 7.0 Solution
# Scraping: Industrial - Entry Level 7.1 (Americas)
# Scraping: Industrial - Entry Level 7.1 (International)
# Scraping: Industrial - Professional and Skilled 7.0 Solution
# Scraping: Account Manager Solution
# Scraping: Administrative Professional - Short Form
# Scraping: Agency Manager Solution
# Scraping: Apprentice + 8.0 Job Focused Assessment
# Scraping: Apprentice 8.0 Job Focused Assessment
# Scraping: Bank Administrative Assistant - Short Form
# Scraping: Bank Collections Agent - Short Form
# Scraping: Bank Operations Supervisor - Short Form
# Scraping: Bilingual Spanish Reservation Agent Solution
# Scraping: Bookkeeping, Accounting, Auditing Clerk Short Form
# Scraping: Branch Manager - Short Form
# Scraping: Cashier Solution
# Scraping: Manager + 7.1 (Americas)
# Scraping: Manager + 7.1 (International)
# Scraping: Manager 7.0 Solution
# Scraping: Manager 7.1 (Americas)
# Scraping: Manager 7.1 (International)
# Scraping: Manager 8.0 JFA
# Scraping: Manager 8.0+ JFA
# Scraping: Manufacturing Production Team Member
# Scraping: Manufacturing Skilled Maintenance Worker
# Scraping: Network Engineer/Analyst Solution
# Scraping: Nurse Leader Solution
# Scraping: Nurse Solution
# Scraping: Nursing Assistant Solution
# Scraping: Personal Banker - Short Form
# Scraping: Phone Banker - Short Form
# Scraping: Prep/Line Cook Solution
# Scraping: Professional + 7.0 Solution
# Scraping: Professional + 7.1 (Americas)
# Scraping: Professional + 7.1 (International)
# Scraping: Professional 7.0 Solution
# Scraping: Professional 7.1 (International)
# Scraping: Professional 8.0 JFA
# Scraping: Professional/Individual Contributor - Short Form
# Scraping: Project Manager - Short Form
# Scraping: Nursing Assistant Solution
# Scraping: Personal Banker - Short Form
# Scraping: Phone Banker - Short Form
# Scraping: Prep/Line Cook Solution
# Scraping: Professional + 7.0 Solution
# Scraping: Professional + 7.1 (Americas)
# Scraping: Professional + 7.1 (International)
# Scraping: Professional 7.0 Solution
# Scraping: Professional 7.1 (International)
# Scraping: Professional 8.0 JFA
# Scraping: Professional/Individual Contributor - Short Form
# Scraping: Project Manager - Short Form
# Scraping: Proof Operator - Processing Specialist -Short Form
# Scraping: Reservation Agent Solution
# Scraping: Restaurant Manager Solution
# Scraping: Restaurant Supervisor Solution
# Scraping: Retail Consultant Solution
# Scraping: Retail Manager w/ Sales Solution
# Scraping: Retail Sales Associate Solution
# Scraping: Sales Director Solution
# Scraping: Sales Engineer Solution
# Scraping: Sales Manager Solution
# Scraping: Sales Professional 7.0 Solution
# Scraping: Sales Professional 7.1 (Americas)
# Scraping: Store Manager 7.1 (International)
# Scraping: Store Manager Solution
# Scraping: Supervisor - Short Form
# Scraping: Supervisor 7.0 Solution
# Scraping: Supervisor 7.1 (Americas)
# Scraping: Supervisor 7.1 (International)
# Scraping: Support Associate Solution
# Scraping: Support Supervisor Solution
# Scraping: Technical Sales Associate Solution
# Scraping: Technician/Technologist Solution
# Scraping: Technology Professional 8.0 Job Focused Assessment
# Scraping: Telenurse Solution
# Scraping: Teller 7.0
# Scraping: Teller with Sales - Short Form
# Scraping: Transcriptionist Solution
# Scraping: Workplace Safety - Individual 7.0 Solution
# Scraping: Workplace Safety - Individual 7.1 (Americas)
# Scraping: Workplace Safety - Team 7.0 Solution
# Scraping: Workplace Safety - Team 7.1 (Americas)
# Scraping: Workplace Safety - Team 7.1 (International)
# Scraping: Workplace Safety Solution
# Scraping completed. Data saved to shl_products.csv
